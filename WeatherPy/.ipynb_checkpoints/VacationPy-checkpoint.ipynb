# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output/output_cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0            ardakan  32.3100   54.0175    300.66        14
# 1        1         georgetown   5.4112  100.3354    300.11        93
# 2        2              lepsy  46.2350   78.9456    279.83        31
# 3        3  wailua homesteads  22.0669 -159.3780    294.59        90
# 4        4       fuglafjordur  62.2440   -6.8140    278.41        67
#
#    Cloudiness  Wind Speed Country        Date
# 0           1        4.48      IR  1683044891
# 1          20        1.54      MY  1683044892
# 2          55        8.85      KZ  1683044892
# 3          40        1.54      US  1683044892
# 4         100        3.28      FO  1683044893

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points(x="Lng", y="Lat", size="Humidity", color = "City", scale = 1)

# Display the map
city_map
# Out:
# :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather = city_data_df.copy()
ideal_weather = ideal_weather.loc[ideal_weather["Cloudiness"] < 20]
ideal_weather = ideal_weather.loc[ideal_weather["Humidity"] > 70]

# Drop any rows with null values
ideal_weather = ideal_weather.dropna()

# Display sample data
ideal_weather.head()
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 11       11       adamstown -25.0660 -130.1015    298.14        74
# 16       16  margaret river -33.9500  115.0667    284.82        87
# 20       20      el granada  37.5027 -122.4694    285.50        86
# 30       30    puerto ayora  -0.7393  -90.3518    304.13        85
# 37       37        bandrele -12.9067   45.1914    301.01        74
#
#     Cloudiness  Wind Speed Country        Date
# 11           6        7.35      PN  1683044895
# 16           0        4.03      AU  1683044897
# 20           0        4.12      US  1683044899
# 30           7        1.79      EC  1683044902
# 37           0        5.66      YT  1683044904

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 11       adamstown      PN -25.0660 -130.1015        74
# 16  margaret river      AU -33.9500  115.0667        87
# 20      el granada      US  37.5027 -122.4694        86
# 30    puerto ayora      EC  -0.7393  -90.3518        85
# 37        bandrele      YT -12.9067   45.1914        74

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accommodation.hotel"
#bias = f"proximity:{lon},{lat}"
limit = 1
params = {
    "categories": categories,
    "radius": radius,
    "limit": limit,
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# adamstown - nearest hotel: No hotel found
# margaret river - nearest hotel: Margaret River Hotel
# el granada - nearest hotel: Beach House
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# bandrele - nearest hotel: Les Baobabs
# waitangi - nearest hotel: Hotel Chathams
# port elizabeth - nearest hotel: Waterford Hotel
# constantia - nearest hotel: Hotel Chérica
# anadyr - nearest hotel: Гостевой дом
# port mathurin - nearest hotel: Escale Vacances
# hawaiian paradise park - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# nemuro - nearest hotel: イーストハーバーホテル
# flying fish cove - nearest hotel: Christmas Island Lodge
# taltal - nearest hotel: Hostería Taltal
# holualoa - nearest hotel: Kona Hotel
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# aasiaat - nearest hotel: SØMA
# piti village - nearest hotel: The Cliff Hotel
# forster - nearest hotel: Hotel Forster
# coquimbo - nearest hotel: Hotel Iberia
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(x="Lng", y="Lat", size="Humidity", hover_cols=["Hotel name", "Country"], color = "City", scale = 1)

# Display the map
map_plot
# Out:
# :Points   [Lng,Lat]   (City,Humidity,Country)
